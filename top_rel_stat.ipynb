# %%
import pandas as pd

from top_rel_stat import top_rel_stat
from get_DepCC import main

# %%
df.head(20)
# Out:
#                    nsubj       ROOT       dobj  freq
# 11             Copyright          ©         al   258
# 304                    I       love         it    59
# 3412              repair       fail      query    53
# 42                    it       feel      weird    45
# 640                    I       have       idea    41
# 464             Parismio        eat         rn    29
# 314                -lsb-      embed      -lsb-    25
# 660                    I  pre-order      Fates    24
# 707                    I      enjoy      waifu    21
# 48                     I     unlock  something    20
# 611                    I        hit    comment    20
# 148                Chile  -lsb-_VBP      -rsb-    17
# 147              Revista     médica      Chile    17
# 706                   it       have   cat-maid    17
# 77                    we     report       case    16
# 23                  what         do         it    15
# 97                     I       have    feeling    15
# ...

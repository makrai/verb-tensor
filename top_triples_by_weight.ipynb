# %%
import configparser

import pandas as pd

config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
df = pd.read_pickle(config['DEFAULT']['ProjectDirectory']+'/dataframe/assoc.pkl')

# %%
columns = ['freq'] + list(df.columns[-7:])

# %% [markdown]
# # _Interaction salience_ and _log Dice salience_ seem the best

# %%
df.sort_values('freq', ascending=False).head()[columns]
# Out:
#                      freq  iact_info      npmi     niact   salience  \
# nsubj ROOT  dobj
# I     think       9398750   0.286190  0.468436  0.040756  76.196102
# it    be          7408077   0.707242  0.168611  0.096021  28.340986
# I     know        4475070   0.212973  0.278992  0.026317  49.882528
# that  be          4339360   0.445843  0.193615  0.054791  34.737479
# I     have        3794298   0.058542  0.010595  0.007027   1.929030
#
#                   iact_sali   log_dice   dice_sali
# nsubj ROOT  dobj
# I     think        6.629316  23.137485  535.957575
# it    be          16.139737  22.776755  519.780761
# I     know         4.705325  22.067628  487.550668
# that  be           9.830406  22.084690  486.946449
# I     have         1.279451  21.759142  475.554795

# %%
df.sort_values('pmi', ascending=False).head()[columns]
# Out:
#                               freq  iact_info  npmi  niact  salience  \
# nsubj      ROOT       dobj
# JFUSgEIilL dgent      memphi     1  30.186154   2.0    1.0       0.0
# Rattus     nurvegigus umur       1  30.186154   2.0    1.0       0.0
# ceham      sawta      quitel     1  30.186154   2.0    1.0       0.0
# Federaci   ó          Lencas     1  30.186154   2.0    1.0       0.0
# serlium    cava       keiba      1  30.186154   2.0    1.0       0.0
#
#                               iact_sali   log_dice  dice_sali
# nsubj      ROOT       dobj
# JFUSgEIilL dgent      memphi        0.0  28.011341        0.0
# Rattus     nurvegigus umur          0.0  28.011341        0.0
# ceham      sawta      quitel        0.0  28.011341        0.0
# Federaci   ó          Lencas        0.0  28.011341        0.0
# serlium    cava       keiba         0.0  28.011341        0.0

# %%
df.sort_values('iact_info', ascending=False).head()[columns]
# Out:
#                                           freq  iact_info  npmi  niact  \
# nsubj      ROOT                dobj
# treigladau cysyniad            sbon          1  30.186154   2.0    1.0
# katılmak   başka               sevinirim     1  30.186154   2.0    1.0
# tahtnr     npfcflld            rhnll         1  30.186154   2.0    1.0
# Ueako      elukpxjeiaebabvaeug ialzne        1  30.186154   2.0    1.0
# Komancb    dwollx              castlo        1  30.186154   2.0    1.0
#
#                                           salience  iact_sali   log_dice  \
# nsubj      ROOT                dobj
# treigladau cysyniad            sbon            0.0        0.0  28.011341
# katılmak   başka               sevinirim       0.0        0.0  28.011341
# tahtnr     npfcflld            rhnll           0.0        0.0  28.011341
# Ueako      elukpxjeiaebabvaeug ialzne          0.0        0.0  28.011341
# Komancb    dwollx              castlo          0.0        0.0  28.011341
#
#                                           dice_sali
# nsubj      ROOT                dobj
# treigladau cysyniad            sbon             0.0
# katılmak   başka               sevinirim        0.0
# tahtnr     npfcflld            rhnll            0.0
# Ueako      elukpxjeiaebabvaeug ialzne           0.0
# Komancb    dwollx              castlo           0.0

# %%
df.sort_values('salience', ascending=False).head()[columns]
# Out:
#                                  freq  iact_info      npmi     niact  \
# nsubj      ROOT      dobj
# ED02       93e       8dba        6573  17.503818  2.000000  1.000000
# imágenes   utilizar  comerciale  4593  18.020933  2.000000  1.000000
# se         encuentra imagen      4593  17.632280  1.978224  0.978433
# Nous       somme     survenue    3945  18.102974  1.985562  0.992469
# whitengrey zellner   whatis      3046  18.613454  2.000000  1.000000
#
#                                    salience   iact_sali   log_dice   dice_sali
# nsubj      ROOT      dobj
# ED02       93e       8dba        443.978617  221.989309  28.011341  355.249248
# imágenes   utilizar  comerciale  438.457278  219.228639  28.011341  340.764158
# se         encuentra imagen      433.683427  214.500582  27.871831  339.066982
# Nous       somme     survenue    432.645345  216.254686  27.922237  333.553729
# whitengrey zellner   whatis      430.815853  215.407926  28.011341  324.166854

# %%
df.sort_values('iact_sali', ascending=False).head()[columns]
# Out:
#                                  freq  iact_info      npmi     niact  \
# nsubj      ROOT      dobj
# ED02       93e       8dba        6573  17.503818  2.000000  1.000000
# imágenes   utilizar  comerciale  4593  18.020933  2.000000  1.000000
# Nous       somme     survenue    3945  18.102974  1.985562  0.992469
# whitengrey zellner   whatis      3046  18.613454  2.000000  1.000000
# se         encuentra imagen      4593  17.632280  1.978224  0.978433
#
#                                    salience   iact_sali   log_dice   dice_sali
# nsubj      ROOT      dobj
# ED02       93e       8dba        443.978617  221.989309  28.011341  355.249248
# imágenes   utilizar  comerciale  438.457278  219.228639  28.011341  340.764158
# Nous       somme     survenue    432.645345  216.254686  27.922237  333.553729
# whitengrey zellner   whatis      430.815853  215.407926  28.011341  324.166854
# se         encuentra imagen      433.683427  214.500582  27.871831  339.066982

# %%
df.sort_values('npmi', ascending=False).head()[columns]
# Out:
#                                                       freq  iact_info  npmi  \
# nsubj                 ROOT            dobj
# #romance              10episode       #gonemaybegone     1  30.186154   2.0
# Báttar                bheós           mhór               1  30.186154   2.0
# FADE                  white/black/red FADE               2  29.186154   2.0
# Biznesa               augstskola      Turiba             1  30.186154   2.0
# it_recipe_stewmeat_03 it_recipe_sting It_Recipe_XP       1  30.186154   2.0
#
#                                                       niact   salience  \
# nsubj                 ROOT            dobj
# #romance              10episode       #gonemaybegone    1.0   0.000000
# Báttar                bheós           mhór              1.0   0.000000
# FADE                  white/black/red FADE              1.0  58.372309
# Biznesa               augstskola      Turiba            1.0   0.000000
# it_recipe_stewmeat_03 it_recipe_sting It_Recipe_XP      1.0   0.000000
#
#                                                       iact_sali   log_dice  \
# nsubj                 ROOT            dobj
# #romance              10episode       #gonemaybegone   0.000000  28.011341
# Báttar                bheós           mhór             0.000000  28.011341
# FADE                  white/black/red FADE            29.186154  28.011341
# Biznesa               augstskola      Turiba           0.000000  28.011341
# it_recipe_stewmeat_03 it_recipe_sting It_Recipe_XP     0.000000  28.011341
#
#                                                       dice_sali
# nsubj                 ROOT            dobj
# #romance              10episode       #gonemaybegone   0.000000
# Báttar                bheós           mhór             0.000000
# FADE                  white/black/red FADE            28.011341
# Biznesa               augstskola      Turiba           0.000000
# it_recipe_stewmeat_03 it_recipe_sting It_Recipe_XP     0.000000

# %%
df.sort_values('niact', ascending=False).head()[columns]
# Out:
#                                                       freq  iact_info  npmi  \
# nsubj             ROOT             dobj
# Original-Datei    erstellt         durchsuchbar         81  23.846304   2.0
# Pseudoalteromonas haloplankti      Pseudoalteromonas    43  24.759890   2.0
# по                прошествии       eshopworld          102  23.513729   2.0
# Caldisphaera      lagunensis       fonti                34  25.098692   2.0
# Nordik            lögfræðiþjónusta Ntrakwah            443  21.394992   2.0
#
#                                                       niact    salience  \
# nsubj             ROOT             dobj
# Original-Datei    erstellt         durchsuchbar         1.0  302.363987
# Pseudoalteromonas haloplankti      Pseudoalteromonas    1.0  268.707434
# по                прошествии       eshopworld           1.0  313.787204
# Caldisphaera      lagunensis       fonti                1.0  255.377322
# Nordik            lögfræðiþjónusta Ntrakwah             1.0  376.173712
#
#                                                        iact_sali   log_dice  \
# nsubj             ROOT             dobj
# Original-Datei    erstellt         durchsuchbar       151.181994  28.011341
# Pseudoalteromonas haloplankti      Pseudoalteromonas  134.353717  28.011341
# по                прошествии       eshopworld         156.893602  28.011341
# Caldisphaera      lagunensis       fonti              127.688661  28.011341
# Nordik            lögfræðiþjónusta Ntrakwah           188.086856  28.011341
#
#                                                        dice_sali
# nsubj             ROOT             dobj
# Original-Datei    erstellt         durchsuchbar       177.587701
# Pseudoalteromonas haloplankti      Pseudoalteromonas  151.996953
# по                прошествии       eshopworld         186.903583
# Caldisphaera      lagunensis       fonti              142.506657
# Nordik            lögfræðiþjónusta Ntrakwah           246.252263

# %%
df.sort_values('log_dice', ascending=False).head()[columns]
# Out:
#                                         freq  iact_info  npmi  niact  \
# nsubj   ROOT                dobj
# Ueako   elukpxjeiaebabvaeug ialzne         1  30.186154   2.0    1.0
# ihiiiuu illmliigtimittt     enil           1  30.186154   2.0    1.0
# Scuole  lombarda            piemontese     1  30.186154   2.0    1.0
# iiber   ebenholz            scch           1  30.186154   2.0    1.0
# Sekilas specnya             kasih          1  30.186154   2.0    1.0
#
#                                         salience  iact_sali   log_dice  \
# nsubj   ROOT                dobj
# Ueako   elukpxjeiaebabvaeug ialzne           0.0        0.0  28.011341
# ihiiiuu illmliigtimittt     enil             0.0        0.0  28.011341
# Scuole  lombarda            piemontese       0.0        0.0  28.011341
# iiber   ebenholz            scch             0.0        0.0  28.011341
# Sekilas specnya             kasih            0.0        0.0  28.011341
#
#                                         dice_sali
# nsubj   ROOT                dobj
# Ueako   elukpxjeiaebabvaeug ialzne            0.0
# ihiiiuu illmliigtimittt     enil              0.0
# Scuole  lombarda            piemontese        0.0
# iiber   ebenholz            scch              0.0
# Sekilas specnya             kasih             0.0

# %%
df.sort_values('dice_sali', ascending=False).head()[columns]
# Out:
#                      freq  iact_info      npmi     niact   salience  \
# nsubj ROOT  dobj
# I     think       9398750   0.286190  0.468436  0.040756  76.196102
# it    be          7408077   0.707242  0.168611  0.096021  28.340986
# I     know        4475070   0.212973  0.278992  0.026317  49.882528
# that  be          4339360   0.445843  0.193615  0.054791  34.737479
# I     have        3794298   0.058542  0.010595  0.007027   1.929030
#
#                   iact_sali   log_dice   dice_sali
# nsubj ROOT  dobj
# I     think        6.629316  23.137485  535.957575
# it    be          16.139737  22.776755  519.780761
# I     know         4.705325  22.067628  487.550668
# that  be           9.830406  22.084690  486.946449
# I     have         1.279451  21.759142  475.554795

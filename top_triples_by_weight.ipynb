# %%
import pandas as pd

# %%
df = pd.read_pickle(config['DEFAULT']['ProjectDirectory']+'dataframe/assoc0to4.pkl')

# %%
columns = ['freq'] + list(df.columns[-7:])

# %%
df[columns].describe(percentiles=[])
# Out:
#                freq     iact_info          npmi         niact      salience  \
# count  1.217660e+07  1.217660e+07  1.217660e+07  1.217660e+07  1.217660e+07
# mean   5.503182e+01  6.094468e-01  3.506251e-01  2.222710e-02  1.315272e+01
# std    1.373986e+03  2.141008e+00  2.937042e-01  7.634537e-02  2.513777e+01
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    2.000000e+00  0.000000e+00  2.939122e-01  0.000000e+00  0.000000e+00
# max    1.130487e+06  2.931980e+01  2.000000e+00  1.000000e+00  4.283700e+02
#
#           iact_sali      log_dice     dice_sali
# count  1.217660e+07  1.217660e+07  1.217660e+07
# mean   9.972956e-01  7.584750e+00  1.779265e+01
# std    4.968944e+00  3.505539e+00  2.890025e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  7.585747e+00  4.700657e+00
# max    2.141136e+02  2.639723e+01  4.698786e+02

# %% [markdown]
# # _Interaction salience_ and _log Dice salience_ seem the best

# %%
df[columns].head()
# Out:
#                        freq  iact_info      npmi     niact    salience  \
# nsubj ROOT dobj
# i     have problem  1130487   0.000000  0.330062  0.000000   61.135843
#       tell you      1050436   0.000000  0.482068  0.000000   89.842341
#       have idea      995894   0.000000  0.331857  0.000000   62.118581
# it    make sense     905214   0.781419  0.863817  0.081979  162.929922
# i     love it        793366   1.061588  0.311401  0.109192   59.331746
#
#                     iact_sali   log_dice   dice_sali
# nsubj ROOT dobj
# i     have problem   0.000000  20.088536  403.950583
#       tell you       0.000000  20.510731  410.267055
#       have idea      0.000000  19.908951  396.698438
# it    make sense    15.462643  22.097761  437.268264
# i     love it       20.804604  20.003936  392.029683

# %%
df.sort_values('pmi', ascending=False).head()[columns]
# Out:
#                                        freq  iact_info  npmi  niact  salience  \
# nsubj         ROOT        dobj
# niincr        tiefirf     grnpowln        1  29.319803   2.0    1.0       0.0
# pleurothallis cordifolia  arvalo          1  29.319803   2.0    1.0       0.0
# exercitum     regno       fredegarius     1  29.319803   2.0    1.0       0.0
# iiayly        cnlloilf.ir rrpiiit         1  29.319803   2.0    1.0       0.0
# ii.k          lluiriilt   cioileheil      1  29.319803   2.0    1.0       0.0
#
#                                        iact_sali   log_dice  dice_sali
# nsubj         ROOT        dobj
# niincr        tiefirf     grnpowln           0.0  26.397231        0.0
# pleurothallis cordifolia  arvalo             0.0  26.397231        0.0
# exercitum     regno       fredegarius        0.0  26.397231        0.0
# iiayly        cnlloilf.ir rrpiiit            0.0  26.397231        0.0
# ii.k          lluiriilt   cioileheil         0.0  26.397231        0.0

# %%
df.sort_values('iact_info', ascending=False).head()[columns]
# Out:
#                                   freq   log_prob       pmi  iact_info  \
# nsubj       ROOT    dobj
# fig.        do      significance     1 -27.183879  0.355827  80.195810
# feature     think   obligation       1 -27.183879  2.833543  78.718094
# institution contain she              1 -27.183879  0.602961  77.626749
# apartment   know    storage          1 -27.183879  4.345226  77.206412
# use         ©       forum            1 -27.183879  3.510308  77.041329
#
#                                   salience  iact_sali  log_dice  dice_sali
# nsubj       ROOT    dobj
# fig.        do      significance       0.0        0.0  3.941427        0.0
# feature     think   obligation         0.0        0.0  6.176014        0.0
# institution contain she                0.0        0.0  5.127459        0.0
# apartment   know    storage            0.0        0.0  5.195947        0.0
# use         ©       forum              0.0        0.0  7.040200        0.0

# %%
df.sort_values('salience', ascending=False).head()[columns]
# Out:
#                                  freq   log_prob        pmi  iact_info  \
# nsubj    ROOT     dobj
# declara  aceptar  images         6124 -14.603621  29.052790  14.758072
# nous     somme    survenue       5336 -14.802336  29.445360  14.894559
# donec    id       turpis        12186 -13.610942  26.790259  14.034657
# sie      diese    fenster        4824 -14.947865  29.491776  15.313739
# mashable redefine storytelling   8759 -14.087329  27.422803  14.839183
#
#                                   salience   iact_sali   log_dice   dice_sali
# nsubj    ROOT     dobj
# declara  aceptar  images        365.491612  185.660357  24.097990  303.158949
# nous     somme    survenue      364.578994  184.417617  24.097726  298.367031
# donec    id       turpis        363.622493  190.491521  23.995605  325.690835
# sie      diese    fenster       360.861786  187.379124  24.013666  293.831556
# mashable redefine storytelling  359.144124  194.342110  23.887493  312.843758

# %%
df.sort_values('iact_sali', ascending=False).head()[columns]
# Out:
#                           freq   log_prob       pmi  iact_info    salience  \
# nsubj  ROOT     dobj
# report see      day       4710 -14.982368  8.818224  35.434109  107.595666
# you    reserve  price     3451 -15.431080  6.034110  36.379306   70.917675
#        provide  we       10870 -13.775815  2.656313  31.791825   35.616020
# people describe you       4119 -15.175801  7.163051  35.436806   86.014478
# you    include  version   3736 -15.316600  2.556605  35.681075   30.339944
#
#                           iact_sali   log_dice   dice_sali
# nsubj  ROOT     dobj
# report see      day      432.349680  16.134910  196.870285
# you    reserve  price    427.558665  13.417128  157.688802
#        provide  we       426.266834  14.840891  198.987616
# people describe you      425.527944  16.020535  192.375835
# you    include  version  423.437261  13.288371  157.696807

# %%
df.sort_values('log_dice', ascending=False).head()[columns]
# Out:
#                                  freq   log_prob        pmi  iact_info  \
# nsubj    ROOT       dobj
# cuarnur  vontel     birlus          1 -27.183879  54.367758  27.183879
# idz      qalallahu  mutawaffika     1 -27.183879  54.367758  27.183879
# woodjame walter1876 1953131         1 -27.183879  54.367758  27.183879
# qwfrrfwb quue       fwcbgmibcd      1 -27.183879  54.367758  27.183879
# yetding  haten      ilsir           1 -27.183879  54.367758  27.183879
#
#                                  salience  iact_sali   log_dice  dice_sali
# nsubj    ROOT       dobj
# cuarnur  vontel     birlus            0.0        0.0  24.151332        0.0
# idz      qalallahu  mutawaffika       0.0        0.0  24.151332        0.0
# woodjame walter1876 1953131           0.0        0.0  24.151332        0.0
# qwfrrfwb quue       fwcbgmibcd        0.0        0.0  24.151332        0.0
# yetding  haten      ilsir             0.0        0.0  24.151332        0.0

# %%
df.sort_values('dice_sali', ascending=False).head()[columns]
# Out:
#                                       freq   log_prob        pmi  iact_info  \
# nsubj     ROOT       dobj
# use       constitute acceptance      76240 -10.965619  18.788082  13.749909
# coating   protect    print           61365 -11.278751  20.538427  13.292732
# account   pend       confirmation    38739 -11.942380  22.828004  12.999062
# inclusion imply      recommendation  33146 -12.167332  21.614139  14.836271
# jump      select     forum           44107 -11.755159  19.456473  15.734951
#
#                                        salience   iact_sali   log_dice  \
# nsubj     ROOT       dobj
# use       constitute acceptance      304.710010  222.999604  23.021309
# coating   protect    print           326.666322  211.422608  23.391421
# account   pend       confirmation    347.932995  198.125194  23.781932
# inclusion imply      recommendation  324.569740  222.789569  23.158991
# jump      select     forum           300.188478  242.770158  22.511379
#
#                                       dice_sali
# nsubj     ROOT       dobj
# use       constitute acceptance      373.365580
# coating   protect    print           372.043557
# account   pend       confirmation    362.472290
# inclusion imply      recommendation  347.768088
# jump      select     forum           347.321766

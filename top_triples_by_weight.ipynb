# %%
import configparser

import pandas as pd

config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
df = pd.read_pickle(config['DEFAULT']['ProjectDirectory']+'/dataframe/assoc.pkl')

# %%
columns = ['freq'] + list(df.columns[-10:])

# %% [markdown]
# # _Interaction salience_ and _log Dice salience_ seem the best

# %%
df.sort_values('freq', ascending=False).head()[columns]
# Out:
#                        freq   log_freq  log_prob       pmi      iact  \
# nsubj ROOT  dobj
# I     think       124841593  26.895523 -6.671204  3.245796  0.346137
# it    be           98405827  26.552240 -7.014487  2.037887  0.614009
# I     know         59471252  25.825689 -7.741038  2.208507  0.268879
# that  be           57715894  25.782465 -7.784262  1.867656  0.361413
# I     have         50336742  25.585109 -7.981619  0.017357  0.106565
#
#                       npmi     niact   pmi_sali  iact_sali      ldice  \
# nsubj ROOT  dobj
# I     think       0.486538  0.051885  87.297370   9.309535  26.859788
# it    be          0.290525  0.087534  54.110460  16.303310  26.553518
# I     know        0.285298  0.034734  57.036202   6.943983  25.790741
# that  be          0.239927  0.046429  48.152784   9.318106  25.817769
# I     have        0.002175  0.013351   0.444074   2.726474  25.454472
#
#                   ldice_sali
# nsubj ROOT  dobj
# I     think       722.408051
# ...

# %%
df.sort_values('pmi', ascending=False).head()[columns]
# Out:
#                                 freq  log_freq   log_prob        pmi  \
# nsubj    ROOT        dobj
# wwq.thai vww.call    B.xxx         1       0.0 -33.566727  67.133455
# Canda    capai       varuvaye      1       0.0 -33.566727  67.133455
# Ruttkamp 8r          18.990        1       0.0 -33.566727  67.133455
# acqua    appiccicose scivolose     1       0.0 -33.566727  67.133455
# agit     célestes    géométrie     1       0.0 -33.566727  67.133455
#
#                                      iact  npmi  niact  pmi_sali  iact_sali  \
# nsubj    ROOT        dobj
# wwq.thai vww.call    B.xxx      33.566727   2.0    1.0       0.0        0.0
# Canda    capai       varuvaye   33.566727   2.0    1.0       0.0        0.0
# Ruttkamp 8r          18.990     33.566727   2.0    1.0       0.0        0.0
# acqua    appiccicose scivolose  33.566727   2.0    1.0       0.0        0.0
# agit     célestes    géométrie  33.566727   2.0    1.0       0.0        0.0
#
# ...

# %%
df.sort_values('iact', ascending=False).head()[columns]
# Out:
#                                                  freq  log_freq   log_prob  \
# nsubj        ROOT           dobj
# mehroh       corhi          liardun                 1       0.0 -33.566727
# moma         arabo          vkdeolarä±.com          1       0.0 -33.566727
# ing_xvmc     using_xvmc_vld using_bindings_perl     1       0.0 -33.566727
# ApJServGroup set1           jserv1.properties       1       0.0 -33.566727
# Otoccpn      ateanntit      zeoyvenawoy             1       0.0 -33.566727
#
#                                                        pmi       iact  npmi  \
# nsubj        ROOT           dobj
# mehroh       corhi          liardun              67.133455  33.566727   2.0
# moma         arabo          vkdeolarä±.com       67.133455  33.566727   2.0
# ing_xvmc     using_xvmc_vld using_bindings_perl  67.133455  33.566727   2.0
# ApJServGroup set1           jserv1.properties    67.133455  33.566727   2.0
# ...

# %%
df.sort_values('pmi_sali', ascending=False).head()[columns]
# Out:
#                                 freq   log_freq   log_prob        pmi  \
# nsubj    ROOT      dobj
# ED02     93e       8dba        85462  16.382995 -17.183732  34.367464
# imágenes utilizar  comerciale  60185  15.877116 -17.689611  35.379222
# Nous     somme     survenue    53824  15.715962 -17.850765  35.451336
# se       encuentra imagen      60185  15.877116 -17.689611  35.023202
# Sie      diese     Fenster     48993  15.580288 -17.986439  35.639338
#
#                                     iact      npmi     niact    pmi_sali  \
# nsubj    ROOT      dobj
# ED02     93e       8dba        17.183732  2.000000  1.000000  563.042002
# imágenes utilizar  comerciale  17.689611  2.000000  1.000000  561.720023
# Nous     somme     survenue    17.721152  1.985984  0.992739  557.151849
# se       encuentra imagen      17.341908  1.979874  0.980344  556.067446
# Sie      diese     Fenster     17.695149  1.981456  0.983805  555.271155
#
# ...

# %%
df.sort_values('iact_sali', ascending=False).head()[columns]
# Out:
#                                 freq   log_freq   log_prob        pmi  \
# nsubj    ROOT      dobj
# ED02     93e       8dba        85462  16.382995 -17.183732  34.367464
# imágenes utilizar  comerciale  60185  15.877116 -17.689611  35.379222
# Nous     somme     survenue    53824  15.715962 -17.850765  35.451336
# Sie      diese     Fenster     48993  15.580288 -17.986439  35.639338
# se       encuentra imagen      60185  15.877116 -17.689611  35.023202
#
#                                     iact      npmi     niact    pmi_sali  \
# nsubj    ROOT      dobj
# ED02     93e       8dba        17.183732  2.000000  1.000000  563.042002
# imágenes utilizar  comerciale  17.689611  2.000000  1.000000  561.720023
# Nous     somme     survenue    17.721152  1.985984  0.992739  557.151849
# Sie      diese     Fenster     17.695149  1.981456  0.983805  555.271155
# se       encuentra imagen      17.341908  1.979874  0.980344  556.067446
#
# ...

# %%
df.sort_values('npmi', ascending=False).head()[columns]
# Out:
#                                                           freq  log_freq  \
# nsubj       ROOT                             dobj
# estaban     hinchada                         contraida       1       0.0
# expéditions d'amundsen                       retrouvées      2       1.0
# reste       interdit                         reste           1       0.0
# Wojueai     nse                              KATIiAIItON     1       0.0
# AR114       9c48e65b6d340f5af24013776fc04e03 00058           1       0.0
#
#                                                            log_prob  \
# nsubj       ROOT                             dobj
# estaban     hinchada                         contraida   -33.566727
# expéditions d'amundsen                       retrouvées  -32.566727
# reste       interdit                         reste       -33.566727
# Wojueai     nse                              KATIiAIItON -33.566727
# AR114       9c48e65b6d340f5af24013776fc04e03 00058       -33.566727
#
# ...

# %%
df.sort_values('niact', ascending=False).head()[columns]
# Out:
#                                                              freq   log_freq  \
# nsubj                 ROOT               dobj
# imágenes              utilizar           comerciale         60185  15.877116
# ED02                  93e                8dba               85462  16.382995
# It_Staff_TitanScepter it_staff_twobladed It_Staff_WarSpear      3   1.584963
# using_firewire        using_iptv         using_ivtv             7   2.807355
# Shànghǎi              dàxué              Nǎiróng                7   2.807355
#
#                                                              log_prob  \
# nsubj                 ROOT               dobj
# imágenes              utilizar           comerciale        -17.689611
# ED02                  93e                8dba              -17.183732
# It_Staff_TitanScepter it_staff_twobladed It_Staff_WarSpear -31.981765
# using_firewire        using_iptv         using_ivtv        -30.759372
# ...

# %%
df.sort_values('ldice', ascending=False).head()[columns]
# Out:
#                                 freq  log_freq   log_prob        pmi  \
# nsubj      ROOT       dobj
# Mamman     ddefki     nmel         1       0.0 -33.566727  67.133455
# torbasus   tasarlamak süslemek     1       0.0 -33.566727  67.133455
# JAP        recid      etock        1       0.0 -33.566727  67.133455
# JFUSgEIilL dgent      memphi       1       0.0 -33.566727  67.133455
# entie      peuptung   homhie       1       0.0 -33.566727  67.133455
#
#                                      iact  npmi  niact  pmi_sali  iact_sali  \
# nsubj      ROOT       dobj
# Mamman     ddefki     nmel      33.566727   2.0    1.0       0.0        0.0
# torbasus   tasarlamak süslemek  33.566727   2.0    1.0       0.0        0.0
# JAP        recid      etock     33.566727   2.0    1.0       0.0        0.0
# JFUSgEIilL dgent      memphi    33.566727   2.0    1.0       0.0        0.0
# entie      peuptung   homhie    33.566727   2.0    1.0       0.0        0.0
#
# ...

# %%
df.sort_values('ldice_sali', ascending=False).head()[columns]
# Out:
#                        freq   log_freq  log_prob       pmi      iact  \
# nsubj ROOT  dobj
# I     think       124841593  26.895523 -6.671204  3.245796  0.346137
# it    be           98405827  26.552240 -7.014487  2.037887  0.614009
# I     know         59471252  25.825689 -7.741038  2.208507  0.268879
# that  be           57715894  25.782465 -7.784262  1.867656  0.361413
# I     have         50336742  25.585109 -7.981619  0.017357  0.106565
#
#                       npmi     niact   pmi_sali  iact_sali      ldice  \
# nsubj ROOT  dobj
# I     think       0.486538  0.051885  87.297370   9.309535  26.859788
# it    be          0.290525  0.087534  54.110460  16.303310  26.553518
# I     know        0.285298  0.034734  57.036202   6.943983  25.790741
# that  be          0.239927  0.046429  48.152784   9.318106  25.817769
# I     have        0.002175  0.013351   0.444074   2.726474  25.454472
#
#                   ldice_sali
# nsubj ROOT  dobj
# I     think       722.408051
# ...

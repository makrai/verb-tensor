# %%
import pickle as pkl

# %%
df = pkl.load(open('/mnt/permanent/home/makrai/project/verb-tensor/top_level/dataframe/assoc0000.pkl', mode='rb'))

# %%
df.describe(percentiles=[])[['freq']+list(df.columns[10:])]
# Out:
#                freq      log_freq      log_dice           pmi     iact_info  \
# count  21099.000000  21099.000000  21099.000000  21099.000000  21099.000000
# mean       1.175506    -14.505894     -6.986015     14.966580     26.078360
# std        2.281821      0.411271      2.601182      5.439371      3.862756
# min        1.000000    -14.598169    -10.814048      0.000000      7.098565
# 50%        1.000000    -14.598169     -7.357552     14.539243     26.350549
# max      258.000000     -6.586942      0.000000     29.196338     37.263720
#
#            salience     iact_sali
# count  21099.000000  21099.000000
# mean    -217.343867   -378.623692
# std       79.684435     58.444325
# min     -426.213067   -543.982075
# 50%     -211.695995   -383.557344
# max       -0.000000    -46.757831

# %% [markdown]
# # Interaction information seems the best

# %%
df.head()
# Out:
#           nsubj   ROOT   dobj  freq  freq_nsubj  freq_ROOT  freq_dobj  \
# 38    Copyright      ©     al   258   -6.126494  -6.086416  -6.570263
# 2023    dtoider   have  party    78   -8.312767  -2.852495  -8.122435
# 847           I   love     it    59   -3.727034  -6.317398  -6.810266
# 782   Gutenberg  ebook  -lrb-    58   -8.715526  -8.715526  -7.586942
# 9411     repair   fail  query    53   -8.870248  -8.816809  -8.790814
#
#       freq_('nsubj', 'ROOT')  freq_('nsubj', 'dobj')  freq_('ROOT', 'dobj')  \
# 38                 -6.126494               -6.586942              -6.581361
# 2023               -8.312767               -8.312767              -8.276241
# 847                -6.685280               -7.803753              -8.620889
# 782                -8.715526               -8.740188              -8.740188
# 9411               -8.870248               -8.870248              -8.870248
#
#       log_freq  log_dice        pmi  iact_info    salience   iact_sali
# ...

# %%
df.sort_values('pmi', ascending=False).head()
# Out:
#            nsubj       ROOT        dobj  freq  freq_nsubj  freq_ROOT  \
# 5876    Spongiae  littorale      Caspii     1  -14.598169 -14.598169
# 2061   Acteocina     smirna        Dall     1  -14.598169 -14.598169
# 9680    Bloggaan      ettei      unohdu     1  -14.598169 -14.598169
# 20251        AVG   immitate         ie6     1  -14.598169 -14.598169
# 20194       Esta   ensalada  adelantado     1  -14.598169 -14.598169
#
#        freq_dobj  freq_('nsubj', 'ROOT')  freq_('nsubj', 'dobj')  \
# 5876  -14.598169              -14.598169              -14.598169
# 2061  -14.598169              -14.598169              -14.598169
# 9680  -14.598169              -14.598169              -14.598169
# 20251 -14.598169              -14.598169              -14.598169
# 20194 -14.598169              -14.598169              -14.598169
#
#        freq_('ROOT', 'dobj')   log_freq  log_dice        pmi  iact_info  \
# 5876              -14.598169 -14.598169       0.0  29.196338  14.598169
# ...

# %%
df.sort_values('iact_info', ascending=False).head()
# Out:
#        nsubj     ROOT     dobj  freq  freq_nsubj  freq_ROOT  freq_dobj  \
# 9798       I  include  diagram     1   -3.727034  -4.218790 -11.598169
# 431        I     show   thrill     1   -3.727034  -4.588340 -13.013206
# 3264    what     have     this     1   -8.870248  -2.852495  -8.870248
# 5421   these     have  process     1   -8.428244  -2.852495  -9.350241
# 14192      I  require  product     1   -3.727034  -7.051274 -11.013206
#
#        freq_('nsubj', 'ROOT')  freq_('nsubj', 'dobj')  freq_('ROOT', 'dobj')  \
# 9798               -13.013206              -14.598169             -14.598169
# 431                -14.598169              -14.598169             -14.598169
# 3264               -14.598169              -13.598169             -14.598169
# 5421               -14.598169              -14.598169             -13.598169
# 14192              -14.598169              -14.598169             -14.598169
#
#         log_freq   log_dice       pmi  iact_info    salience   iact_sali
# ...

# %%
df.sort_values('salience', ascending=False).head()
# Out:
#       nsubj  ROOT      dobj  freq  freq_nsubj  freq_ROOT  freq_dobj  \
# 11938    we  have      role     1   -4.249441  -2.852495  -7.350241
# 10005     I  have    number     1   -3.727034  -2.852495  -8.043580
# 9555     we  have      time     1   -4.249441  -2.852495  -7.609484
# 16224     I  have  evidence     1   -3.727034  -2.852495  -8.276241
# 15645    we  have    result     1   -4.249441  -2.852495  -7.765279
#
#        freq_('nsubj', 'ROOT')  freq_('nsubj', 'dobj')  freq_('ROOT', 'dobj')  \
# 11938               -6.998256              -13.013206              -9.553775
# 10005               -5.866850              -14.598169              -9.954313
# 9555                -6.998256              -11.790814              -9.954313
# 16224               -5.866850              -14.598169             -13.013206
# 15645               -6.998256              -10.790814             -13.013206
#
#         log_freq   log_dice       pmi  iact_info  salience   iact_sali
# ...

# %%
df.sort_values('iact_sali', ascending=False).head()
# Out:
#           nsubj     ROOT          dobj  freq  freq_nsubj  freq_ROOT  \
# 38    Copyright        ©            al   258   -6.126494  -6.086416
# 9411     repair     fail         query    53   -8.870248  -8.816809
# 782   Gutenberg    ebook         -lrb-    58   -8.715526  -8.715526
# 124      author  declare      conflict    52   -7.340781  -8.643973
# 1669  residency  explore  intersection    38   -9.350241  -8.331382
#
#       freq_dobj  freq_('nsubj', 'ROOT')  freq_('nsubj', 'dobj')  \
# 38    -6.570263               -6.126494               -6.586942
# 9411  -8.790814               -8.870248               -8.870248
# 782   -7.586942               -8.715526               -8.740188
# 124   -8.489644               -8.790814               -8.598169
# 1669  -9.350241               -9.350241               -9.350241
#
#       freq_('ROOT', 'dobj')  log_freq  log_dice        pmi  iact_info  \
# 38                -6.581361 -6.586942 -0.341920  12.196231   7.098565
# ...

# %%
df.sort_values('log_dice', ascending=False).head()
# Out:
#          nsubj         ROOT        dobj  freq  freq_nsubj  freq_ROOT  \
# 4338   Ecology     unintend  Engagement     1  -14.598169 -14.598169
# 9600       Los          sim   accesorio     1  -14.598169 -14.598169
# 1911    Coryne  vanbenedeni      Hincks     1  -14.598169 -14.598169
# 4964   menghia         roti       tawar     1  -14.598169 -14.598169
# 19040  Vintage       rebuke    chairman     1  -14.598169 -14.598169
#
#        freq_dobj  freq_('nsubj', 'ROOT')  freq_('nsubj', 'dobj')  \
# 4338  -14.598169              -14.598169              -14.598169
# 9600  -14.598169              -14.598169              -14.598169
# 1911  -14.598169              -14.598169              -14.598169
# 4964  -14.598169              -14.598169              -14.598169
# 19040 -14.598169              -14.598169              -14.598169
#
#        freq_('ROOT', 'dobj')   log_freq  log_dice        pmi  iact_info  \
# 4338              -14.598169 -14.598169       0.0  29.196338  14.598169
# ...

# %%
#!/usr/bin/env python
# coding: utf-8

# %%
from collections import defaultdict
import glob
import itertools
import os
import pandas as pd
import pickle
import lzma

from conllu import parse, parse_incr
import numpy as np

import logging
logging.basicConfig(level=logging.DEBUG, format='%(levelname)-8s [%(lineno)d] %(message)s')

# %%
proj_dir = '/mnt/store/home/makrai/project/verb-tensor/'

def get_umbc_dict():
    dict_filen = os.path.join(proj_dir, 'umbc_freq.pkl')
    if os.path.exists(dict_filen):
        return pickle.load(open(dict_filen, mode='rb'))
    umbc_dir = '/mnt/store/home/makrai/data/language/english/corp/umbc_WebBase/English/'
    freq = defaultdict(int)
    for filen in glob.glob(os.path.join(umbc_dir, 'en-common_crawl-*.conllu.xz')):
        logging.info(filen)
        for i, sentence in  enumerate(parse_incr(lzma.open(os.path.join(
                umbc_dir, filen), mode='rt', encoding="utf-8"))):
            if not i % 100000:
                logging.debug(i)
            root = sentence.to_tree()
            subj, obj = '', ''
            for child in root.children:
                if 'subj' in child.token['deprel']:
                    if subj:
                        #logging.warn('subj: {}'.format((subj, child.token['lemma'], sentence)))
                        continue
                    subj = child.token['lemma']
                elif child.token['deprel'] == 'obj':
                    if obj:
                        #logging.warn('obj: {}'.format((obj, child.token['lemma'], sentence)))
                        continue            
                    obj = child.token['lemma']
            #if bool(obj) and bool(subj):
            freq[(subj, root.token['lemma'], obj)] += 1
        pickle.dump(freq, open(dict_filen, mode='wb'))
    return freq

# %%
def get_umbc_df():
    freq = get_umbc_dict()
    freq_df = pd.DataFrame.from_records(list(freq.items()), columns=['svo', 'freq'])
    freq_df[['subj', 'verb', 'obj']] = pd.DataFrame(freq_df.svo.tolist(),
            index=freq_df.index)
    del freq_df['svo']
    df.sort_values('freq', ascending=False).to_csv(os.path.join(proj_dir, 'umbc_freq.csv'), sep='\t', index=False)
    return freq_df

# %%
df = get_umbc_df()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-5-575ce7bbc661> in <module>
# ----> 1 df = get_umbc_df()
#
# <ipython-input-4-5975a24f9349> in get_umbc_df()
#       1 def get_umbc_df():
# ----> 2     freq = get_umbc_dict()
#       3     freq_df = pd.DataFrame.from_records(list(freq.items()), columns=['svo', 'freq'])
#       4     freq_df[['subj', 'verb', 'obj']] = pd.DataFrame(freq_df.svo.tolist(),
#       5             index=freq_df.index)
#
# <ipython-input-3-42e9a83700ca> in get_umbc_dict()
#       4     dict_filen = os.path.join(proj_dir, 'umbc_freq.pkl')
#       5     if os.path.exists(dict_filen):
# ----> 6         return pickle.load(open(dict_filen, mode='rb'))
#       7     umbc_dir = '/mnt/store/home/makrai/data/language/english/corp/umbc_WebBase/English/'
#       8     freq = defaultdict(int)
#
# EOFError: Ran out of input

# %%
pickle.load(open('/mnt/store/home/makrai/project/verb-tensor/umbc_freq.pkl_', mode='rb'))
# Out:
# defaultdict(int,
#             {('oven', 'work', ''): 4,
#              ('', 'neighbors', ''): 25,
#              ('', 'find', 'home'): 26,
#              ('', 'hour', ''): 1890,
#              ('', 'terrorist', ''): 55,
#              ('', 'Book', ''): 905,
#              ('', 'bro', ''): 74,
#              ('', 'Rothenbuhler', ''): 2,
#              ('', 'replace', ''): 98,
#              ('it', 'dig', ''): 6,
#              ('token', 'unique', ''): 4,
#              ('GT', 'feel', ''): 1,
#              ('Ochratoxin', 'damaging', ''): 1,
#              ('', 'dinner', ''): 491,
#              ('', 'back', ''): 1503,
#              ('love', 'Pound', ''): 1,
#              ('', 'forum', ''): 859,
#              ('Holcombe', 'b.', ''): 1,
#              ('you', 'get', 'what'): 130,
#              ('', 'Swell', ''): 13,
#              ('', 'make', 'measurement'): 4,
#              ('Brown', 'rag', ''): 1,
#              ('', 'location', ''): 7063,
#              ('', 'Msrp', ''): 173,
#              ('Jobs', 'hire', ''): 35,
#              ('we', 'take', 'look'): 119,
#              ('', 'surround', ''): 67,
#              ('', '#', ''): 11492,
#              ('site', 'estimate', ''): 11,
#              ('', 'paint', ''): 388,
#              ('it', 'adhere', ''): 3,
#              ('', 'plot', ''): 1216,
#              ('they', 'have', 'incentive'): 2,
#              ('', 'SC', ''): 172,
#              ('bag', 'carry', 'all'): 1,
#              ('pet', 'include', ''): 7,
#              ('', 'quote', ''): 4307,
#              ('collection', 'prove', 'shot'): 1,
#              ('', 'Hot', ''): 263,
#              ('Vegas', 'what', ''): 3,
#              ('I', 'get', 'eye'): 6,
#              ('', 'Recap', ''): 282,
#              ('Impossibility', 'bear', ''): 1,
#              ('I', 'have', 'time'): 528,
#              ('they', 'able', ''): 348,
#              ('', 'quality', ''): 893,
#              ('', 'CW', ''): 20,
#              ('', 'Crush', 'cracker'): 1,
#              ('', 'let', 'we'): 1358,
#              ('', 'settlement', ''): 287,
#              ('', '04/12/1983', ''): 1,
#              ('slide', 'usual', ''): 1,
#              ('', 'Quilt', ''): 60,
#              ('Yamamoto', 'dead', ''): 1,
#              ('', 'find', 'post'): 5809,
#              ('', 'story', ''): 2935,
#              ('Bob', 'say', ''): 80,
#              ('that', 'example', ''): 19,
#              ('', 'employment', ''): 320,
#              ('', 'gold', ''): 1750,
#              ('it', 'root', ''): 17,
#              ('that', 'change', 'fact'): 6,
#              ('professor', 'have', 'Atheist'): 1,
#              ('duty', 'training', ''): 1,
#              ('find', 'need', ''): 1,
#              ('', 'judgement', ''): 37,
#              ('she', 'die', ''): 282,
#              ('baby', 'stay', 'high'): 1,
#              ('I', 'think', ''): 27511,
#              ('', 'life', ''): 6180,
#              ('we', 'celebrate', 'end'): 1,
#              ('imgur.com', 'place', ''): 1,
#              ('', 'way', ''): 3766,
#              ('open', 'set', ''): 2,
#              ('York', 'want', 'law'): 1,
#              ('Peter', 'sigh', ''): 1,
#              ('', "'num_row", ''): 3,
#              ('', 'Jl', ''): 24,
#              ('Valparaiso', 'return', ''): 2,
#              ('', 'shop', ''): 2282,
#              ('', 'part', ''): 4384,
#              ('', 'answer', ''): 1313,
#              ('', 'talk', 'toy'): 1,
#              ('reputation', 'grow', ''): 5,
#              ('letter', 'attempt', ''): 3,
#              ('', 'interview', ''): 2650,
#              ('they', 'say', ''): 1099,
#              ('', 'share', ''): 2012,
#              ('twist', 'come', ''): 2,
#              ('', 'Hodgepodge', ''): 2,
#              ('CHFруб', 'RUB$', 'MXNRs'): 4,
#              ('', 'Kelly', ''): 286,
#              ('frequency', 'vary', ''): 1,
#              ('', 'June', ''): 5630,
#              ('', 'AMeds.com', ''): 1,
#              ('track', 'environment', ''): 1,
#              ('', 'Hoag', 'work'): 1,
#              ('RewriteRule', '1:$', 'QSA,L'): 1,
#              ('', 'collection', ''): 4424,
#              ('', 'deal', ''): 1912,
#              ('I', 'want', 'knee'): 1,
#              ('', 'Safety', ''): 263,
#              ('', 'Buddhify', ''): 1,
#              ('texture', 'give', ''): 1,
#              ('', 'CB&I', ''): 1,
#              ('group', 'open', 'world'): 1,
#              ('role', 'require', 'background'): 1,
#              ('', 'B', ''): 1352,
#              ('', 'setCustomFlag', ''): 1,
#              ('', 'seek', 'protection'): 4,
#              ('', 'Program2533', ''): 1,
#              ('we', 'fix', 'this'): 11,
#              ('', 'Warsaw', ''): 14,
#              ('', 'stress', 'rejection'): 2,
#              ('J', 'say', ''): 4,
#              ('we', 'optimist', ''): 2,
#              ('University', 'become', ''): 2,
#              ('', 'post', ''): 35599,
#              ('accelerated', 'release', 'Holstein'): 1,
#              ('that', 'feel', ''): 51,
#              ('he', 'Hof', ''): 1,
#              ('he', 'father', ''): 90,
#              ('part', 'Info$', 'AvailableWheels'): 1,
#              ('those', 'dive', ''): 1,
#              ('', 'Shave', ''): 21,
#              ('whoever', 'fault', ''): 1,
#              ('woman', 'work', ''): 19,
#              ('', 'settings', ''): 48,
#              ('cat', 'easier', ''): 1,
#              ('Plastic_x2002.01.23', 'arent', 'all'): 1,
#              ('you', 'have', 'enough'): 5,
#              ('', 'centers', ''): 271,
#              ('team', 'excel', ''): 2,
#              ('LACC', 'recipient', ''): 1,
#              ('ReplyDeleteRepliesRoman', 'get', 'mobile'): 1,
#              ('Fitzgerald', 'rule', ''): 1,
#              ('', '800.688.4232', ''): 1,
#              ('', 'statione', ''): 12,
#              ('', 'glad', ''): 1177,
#              ('', 'child', ''): 1360,
#              ('', 'Charles', ''): 1631,
#              ('', 'ha', ''): 123,
#              ('Ninoy', 'bombing', ''): 1,
#              ('', 'true', ''): 763,
#              ('charter', 'broader', ''): 1,
#              ('Lukashenko', 'winger', ''): 1,
#              ('advance', 'be', ''): 3,
#              ('we', 'sit', ''): 142,
#              ('we', 'talk', ''): 662,
#              ('I', 'go', ''): 6624,
#              ('', 'visit', ''): 2628,
#              ('', 'singles', ''): 945,
#              ('I', 'discover', 'blog'): 13,
#              ('', 'go', ''): 8675,
#              ('owner', 'consider', 'themselves'): 1,
#              ('he', 'respond', ''): 77,
#              ('mb', 'more', ''): 1,
#              ('I', 'do', 'electronic'): 1,
#              ('', 'Caption\\', ''): 6,
#              ('', 'member', ''): 3831,
#              ('program', 'design', ''): 110,
#              ('', 'truck', ''): 342,
#              ('it', 'difficult', ''): 218,
#              ('it', 'attempt', ''): 65,
#              ('they', 'want', ''): 518,
#              ('that', 'be', ''): 2165,
#              ('I', 'sorry', ''): 1213,
#              ('', 'hang', 'facebook'): 1,
#              ('', 'Van', ''): 358,
#              ('country', 'protect', 'freeloader'): 1,
#              ('I', 'nurse', 'crush'): 1,
#              ('Catamount', 'score', 'point'): 1,
#              ('Yall', 'know', ''): 1,
#              ('', 'agoT17m', ''): 279,
#              ('', 'announce', 'actress'): 1,
#              ('', 'bed', ''): 433,
#              ('I', 'use', 'it'): 480,
#              ('', 'Cardinals', ''): 39,
#              ('', 'source', ''): 4782,
#              ('', 'updated', ''): 304,
#              ('', 'skate', ''): 12,
#              ('you', 'have', 'bag'): 5,
#              ('bread', 'make', ''): 4,
#              ('', '...', ''): 968,
#              ('', 'have', 'stages'): 1,
#              ('', 'patch', ''): 206,
#              ('I', 'economist', ''): 4,
#              ('essence', 'deliver', ''): 1,
#              ('clickwrap', 'override', 'law'): 1,
#              ('', 'Ranger', ''): 333,
#              ('10', 'receive', 'statement'): 1,
#              ('you', 'end', ''): 158,
#              ('sister', 'circuit', ''): 1,
#              ('Boron', 'mineral', ''): 2,
#              ('', 'L1', ''): 39,
#              ('', 'ReporterBack', ''): 7,
#              ('', 'Library', ''): 1028,
#              ('', 'detail', ''): 2941,
#              ('complaint', 'service', ''): 1,
#              ('', 'player', ''): 2744,
#              ('upgrade', 'have', 'effect'): 1,
#              ('Jesus', 'come', ''): 26,
#              ('', 'Grit', ''): 27,
#              ('voter', 'approve', 'tax'): 2,
#              ('I', 'recommend', 'market'): 1,
#              ('', 'determine', ''): 377,
#              ('', 'Sticker', ''): 32,
#              ('event', 'feature', 'performance'): 1,
#              ('I', 'take', 'picture'): 69,
#              ('petition', 'claim', ''): 1,
#              ('', 'yes', ''): 464,
#              ('I', 'deside', 'that'): 1,
#              ('I', 'cry', ''): 134,
#              ('Jefferson', 'leave', ''): 1,
#              ('', 'stock', ''): 873,
#              ('', 'price', ''): 8454,
#              ('men', 'face', 'past'): 1,
#              ('', 'more', ''): 5110,
#              ('', 'retrieve', ''): 4625,
#              ('2d', 'bonus', ''): 1,
#              ('Range', 'introduce', ''): 1,
#              ('', 'shade', ''): 228,
#              ('', '$', ''): 19559,
#              ('tip', 'here', ''): 129,
#              ('you', 'own', 'share'): 1,
#              ('', 'Apn', ''): 10,
#              ('', 'deny', ''): 88,
#              ('', 'Talmud', ''): 13,
#              ('', 'excellence', ''): 90,
#              ('', 'have', 'launch'): 1,
#              ('', 'write', ''): 8737,
#              ('', 'Sunday', ''): 1749,
#              ('', 'Tag', ''): 4853,
#              ('', 'service', ''): 5358,
#              ('', 'court', ''): 625,
#              ('', 'piece', ''): 1355,
#              ('center', 'unit', 'that'): 1,
#              ('I', 'lucky', ''): 234,
#              ('', 'let', 'book'): 3,
#              ('', 'Mayacamas', ''): 1,
#              ('', 'create', 'dialogue'): 1,
#              ('sheet', 'help', 'Americans'): 1,
#              ('', 'leads', ''): 36,
#              ('store', 'message', ''): 2,
#              ('', 'thesis', ''): 215,
#              ('I', 'pause', 'music'): 3,
#              ('', 'let', 'us'): 1114,
#              ('', 'Sydney', ''): 169,
#              ('', 'body', ''): 1033,
#              ('', 'good', ''): 1519,
#              ('', 'Asimkin0934426996', ''): 1,
#              ('Llrc', 'see', ''): 1,
#              ('', 'stay', ''): 1696,
#              ('', 'debate', ''): 355,
#              ('we', 'stylize', 'handkerchief'): 2,
#              ('', 'thank', 'God'): 106,
#              ('', 'Rabbits', ''): 5,
#              ('I', 'prouder', ''): 2,
#              ('experts', 'over', ''): 1,
#              ('', 'language', ''): 1608,
#              ('Sochi', 'host', 'games'): 1,
#              ('darkness', 'be', ''): 10,
#              ('line', 'seem', ''): 10,
#              ('', 'Bethel', ''): 57,
#              ('', 'pain', ''): 411,
#              ('spokesperson', 'say', ''): 55,
#              ('', 'Louisville', ''): 198,
#              ('slot', 'transmit', ''): 2,
#              ('combination', 'use', ''): 16,
#              ('', 'time', ''): 8603,
#              ('', 'subject', ''): 6834,
#              ('who', 'singer', ''): 1,
#              ('', 'position', ''): 2052,
#              ('', 'say', ''): 6029,
#              ('system', 'customizable', ''): 1,
#              ('Cath', 'sit', ''): 1,
#              ('she', 'believe', ''): 80,
#              ('', '73', ''): 197,
#              ('Intel', 'e-mail', 'I'): 3,
#              ('', 'book', ''): 2907,
#              ('', 'profile', ''): 2972,
#              ('Meyer', 'say', ''): 11,
#              ('many', 'servitude', ''): 1,
#              ('', 'claim', ''): 686,
#              ('', 'theatre', ''): 987,
#              ('Babs', 'lover', ''): 1,
#              ('they', 'do', 'change'): 3,
#              ('point', 'arrive', ''): 2,
#              ('', '#4', ''): 31,
#              ('', 'injury', ''): 281,
#              ('program', 'strengthene', ''): 1,
#              ('', 'recording', ''): 283,
#              ('', 'have', 'Thanksgiving'): 11,
#              ('', 'note', ''): 13447,
#              ('', 'wedding', 'DIy'): 1,
#              ('', 'materials', ''): 485,
#              ('', 'reply', 'Fav'): 13,
#              ('', 'Acquisition', ''): 107,
#              ('this', 'apply', ''): 143,
#              ('', 'support', ''): 2473,
#              ('I', 'ajust', 'solution'): 1,
#              ('I', 'suggest', ''): 727,
#              ('', 'meeting', ''): 1312,
#              ('', '....', ''): 27,
#              ('', 'W', ''): 85,
#              ('unit', 'fabricate', ''): 1,
#              ('C$', '$', ''): 1,
#              ('you', 'think', 'what'): 879,
#              ('', 'Trans', ''): 122,
#              ('I', 'continue', ''): 310,
#              ('', 'Andrew', ''): 617,
#              ('', 'raw', ''): 25,
#              ('Hill', 'figure', ''): 1,
#              ('book', 'start', ''): 13,
#              ('party', 'he', ''): 1,
#              ('prediction', 'way', ''): 1,
#              ('release', 'plan', ''): 5,
#              ('', 'series', ''): 1529,
#              ('they', 'host', 'series'): 2,
#              ('', 'fishing', 'Forum'): 7,
#              ('let', 'say', ''): 30,
#              ('', 'Soundbite', ''): 121,
#              ('color', 'lose', ''): 1,
#              ('', '10kWatchtower', ''): 1,
#              ('they', '’re', 'commodity'): 1,
#              ('', 'face', ''): 808,
#              ('', 'Angeles', ''): 201,
#              ('', 'project', ''): 2451,
#              ('manager', 'support', 'more'): 1,
#              ('', 'editor', ''): 724,
#              ('', 'Dan', ''): 618,
#              ('', 'cutlet', ''): 7,
#              ('', 'kern-bug-people&#64;netbsd.org', ''): 46,
#              ('simplex', 'ask', 'Jul'): 3,
#              ('we', 'take', ''): 115,
#              ('I', 'hate', 'list'): 2,
#              ('Bulmer', 'say', 'that'): 1,
#              ('', 'interrupt', ''): 33,
#              ('clay', 'b.', ''): 3,
#              ('', 'Jan', ''): 2564,
#              ('', 'follow', ''): 1102,
#              ('attendance', '%', ''): 1,
#              ('Man', 'Honor', ''): 1,
#              ('', 'Defcsp420_cvt', ''): 1,
#              ('', 'thing', ''): 4319,
#              ('', 'Loxodonta', ''): 5,
#              ('', 'update', ''): 5411,
#              ('I', 'pick', 'TV'): 1,
#              ('', 'minute', ''): 1192,
#              ('', '.+', ''): 56,
#              ('Wat', 'chef', ''): 1,
#              ('', 'Kernel', ''): 613,
#              ('name', 'Yousef', ''): 1,
#              ('they', 'attract', 'attention'): 1,
#              ('type', 'be', ''): 403,
#              ('that', 'restart', ''): 1,
#              ("'I", 'call', ''): 1,
#              ('', 'feature', ''): 3552,
#              ('tea', 'drank', ''): 2,
#              ('I', 'use', 'piece'): 13,
#              ('', 'history', ''): 10521,
#              ('', 'cream', ''): 245,
#              ('', 'release', ''): 3520,
#              ('I', 'point', ''): 191,
#              ('what', 'up', ''): 100,
#              ('I', 'find', 'myself'): 152,
#              ('', 'March', ''): 6722,
#              ('look', 'package', ''): 1,
#              ('we', 'feature', 'recipes'): 1,
#              ('', 'up', ''): 2796,
#              ('store', 'stock', ''): 3,
#              ('', 'light', ''): 1125,
#              ('you', 'get', 'it'): 196,
#              ('', 'mb', ''): 409,
#              ('Yang', 'Yahoo', ''): 1,
#              ('', 'warning', ''): 769,
#              ('it', 'be', ''): 2674,
#              ('I', 'see', 'error'): 9,
#              ('tough', 'I', ''): 3,
#              ('man', 'suitcase', ''): 1,
#              ('', 'Henry', ''): 701,
#              ('Deibler', 'painter', ''): 1,
#              ('', 'arxiv:1407.8234', ''): 1,
#              ('we', 'need', 'hand'): 1,
#              ('', 'journey', ''): 424,
#              ('we', 'have', 'conversation'): 22,
#              ('', 'Sinlges', ''): 1,
#              ('Summers', 'like', 'shorts'): 1,
#              ('', 'Wickedness', ''): 1,
#              ('', 'obviously', ''): 11,
#              ('', 'distinction', ''): 63,
#              ('fries', 'normal', ''): 1,
#              ('', 'add', 'Opacity'): 15,
#              ('', 'today', ''): 3916,
#              ('way', 'what', ''): 191,
#              ('', 'work', ''): 5835,
#              ('stabilization', 'complete', ''): 1,
#              ('director', 'say', ''): 116,
#              ('', 'sure', ''): 3219,
#              ('characters', 'cite', ''): 1,
#              ('submarine', 'program', ''): 1,
#              ('', 'Tags', ''): 494,
#              ('', 'Feminine', ''): 24,
#              ('what', 'trigger', ''): 3,
#              ('', 'aspect', ''): 363,
#              ('', 'Package', ''): 366,
#              ('', '-9', ''): 66,
#              ('they', 'roar', ''): 3,
#              ('', 'ask', 'question'): 589,
#              ('', 'contact', ''): 2034,
#              ('teacher', 'serve', 'we'): 1,
#              ('', 'home', ''): 8018,
#              ('', 'reply', ''): 12414,
#              ('', 'blog', ''): 3415,
#              ('music', 'part', ''): 9,
#              ('mom', 'recommend', 'it'): 1,
#              ('', 'circumstance', ''): 88,
#              ('', 'manual', ''): 415,
#              ('court', 'guilty', ''): 1,
#              ('', 'InterPro', ''): 1,
#              ('', 'discussion', ''): 1807,
#              ('', 'coordinate', ''): 80,
#              ('re-enactor', 'visit', 'school'): 1,
#              ('', 'help', 'I'): 296,
#              ('', 'fleshlight', ''): 2,
#              ('Taxonomist', 'formulate', 'set'): 1,
#              ('Yojimbo', 'go', ''): 1,
#              ('', 'Apartments', ''): 250,
#              ('', 're-', ''): 11,
#              ('law', 'exist', ''): 4,
#              ('', 'School', ''): 5712,
#              ('girl', 'love', 'it'): 6,
#              ('Pulminologist', 'what', ''): 1,
#              ('we', 'heal', ''): 3,
#              ('', 'have', ''): 2637,
#              ('', 'viewing', 'record'): 4,
#              ('', 'try', 'some'): 19,
#              ('area', 'use', ''): 33,
#              ('I', 'say', ''): 5456,
#              ('', 'c0a98d4f,3,c0aba30c,fdf27a34,3,...', ''): 1,
#              ('', 'poster', ''): 688,
#              ('war', 'end', ''): 31,
#              ('', 'depth', ''): 396,
#              ('', 'copyright', ''): 3869,
#              ('ask', 'threat', ''): 3,
#              ('operation', 'keep', 'comfort'): 1,
#              ('', 'noise', ''): 175,
#              ('we', 'have', 'out'): 2,
#              ('Center', 'open', ''): 37,
#              ('', 'respond', ''): 393,
#              ('', 'let', "'s"): 2855,
#              ('cascade', 'say', ''): 1,
#              ('this', 'part', ''): 297,
#              ('blueBankmobileAllianzgraphchartAdvisorfinancialbalancemoneytradingallianz',
#               'bank',
#               'application'): 1,
#              ('', 'article', ''): 4140,
#              ('reason', 'be', ''): 2033,
#              ('I', 'store', ''): 19,
#              ('', 'Img_1572_press_reconstructed.jpg', ''): 1,
#              ('I', 'bet', 'cash'): 1,
#              ('', 'info', ''): 1734,
#              ('I', 'want', ''): 6465,
#              ('I', 'use', 'list'): 4,
#              ('student', 'kind', ''): 4,
#              ('', 'Gatecrasher', ''): 1,
#              ('it', 'impossible', ''): 134,
#              ('Anna', 'rub', 'model'): 1,
#              ('', 'capacity', ''): 598,
#              ('', 'live', 'life'): 27,
#              ('bold', 'blend', ''): 1,
#              ('I', 'see', 'scripture'): 1,
#              ('', 'line', ''): 2829,
#              ('start', 'exercise', ''): 1,
#              ('talent', 'adapt', 'structure'): 3,
#              ('play', 'set', 'pace'): 1,
#              ('', 'September', ''): 5577,
#              ('there', 'be', ''): 16,
#              ('', 'save', 'golf'): 1,
#              ('', 'dispose', ''): 39,
#              ('', 'Disapppointment', ''): 1,
#              ('', 'Liliana', ''): 3,
#              ('we', 'find', 'Z'): 2,
#              ('fi', 'connect', ''): 1,
#              ('', 'suppliers', ''): 56,
#              ('manners', 'style', ''): 1,
#              ('I', 'have', 'pan'): 10,
#              ('', 'Hill', ''): 884,
#              ('', 'fact', ''): 992,
#              ('neighborhood', 'find', 'reason'): 2,
#              ('she', 'desperate', 'Boy'): 1,
#              ('', 'limit', 'photo'): 1,
#              ('', '2.i', ''): 1,
#              ('Triple', 'best', ''): 1,
#              ('industry', 'use', 'gas'): 1,
#              ('Meg', 'right', ''): 1,
#              ('', 'set', ''): 5013,
#              ('', 'boat', ''): 135,
#              ('people', 'different', ''): 8,
#              ('', 'target', ''): 392,
#              ('conflict', 'acclaim', ''): 1,
#              ('', 'search', 'reston_pant'): 1,
#              ('I', 'empty', 'mouse'): 1,
#              ('', 'seek', ''): 182,
#              ('gem', 'space', ''): 1,
#              ('', 'make', ''): 4624,
#              ('item', 'piece', ''): 1,
#              ('', 'NJ', ''): 148,
#              ('', 'Incidence', ''): 30,
#              ('', 'Lifeline', ''): 10,
#              ('', 'file', ''): 3567,
#              ('', 'Roxy', ''): 14,
#              ('', 'revision', ''): 1210,
#              ('fact', 'make', 'I'): 18,
#              ('', 'play', 'role'): 67,
#              ('', 'Steve', ''): 937,
#              ('',
#               'url=http://it.moha.gov.my/CFIDE/cheap/Latest-Collection-Of-Louis-Vuitton-Handbags-Qht9ny.html',
#               ''): 1,
#              ('we', 'need', 'actor'): 1,
#              ('', 'restaurant', ''): 1100,
#              ('', 'Pause', ''): 19,
#              ('', 'param', ''): 18,
#              ('time', 'be', ''): 629,
#              ('', 'Comics', ''): 469,
#              ('it', 'thing', ''): 808,
#              ('feature', 'allow', 'you'): 23,
#              ('Office', 'destroie', 'country'): 2,
#              ('haBwve', 'major', ''): 3,
#              ('we', 'keep', ''): 113,
#              ('it', 'sharp', ''): 8,
#              ('cartridge', 'last', ''): 3,
#              ('', 'engineer', 'room'): 125,
#              ('', 'category', ''): 8026,
#              ('', 'version', ''): 3811,
#              ('', 'Notex', ''): 93,
#              ('', 'Gearbag', 'VCOM'): 1,
#              ('review', 'glowing', ''): 1,
#              ('bro', 'charter', 'yacht'): 1,
#              ('', 'Barbados', ''): 16,
#              ('', 'refer', ''): 1250,
#              ('', 'Hmmm', ''): 15,
#              ('', 'three', ''): 534,
#              ('County', 'have', 'program'): 3,
#              ('', 'marriage', ''): 533,
#              ('', 'word', ''): 2113,
#              ('', 'test', ''): 1443,
#              ('', 'video', ''): 5327,
#              ('I', 'look', ''): 3779,
#              ('', 'season1', ''): 1,
#              ('toy', 'beginner', ''): 1,
#              ('', 'id', ''): 1748,
#              ('', 'John', ''): 6573,
#              ('it', 'remain', ''): 198,
#              ('we', 'know', ''): 2251,
#              ('day', 'gone', ''): 16,
#              ('calibration', 'charge', ''): 1,
#              ('', 'have', 'trip'): 29,
#              ('', 'reply', '#'): 11106,
#              ('you', 'need', ''): 4094,
#              ('', 'area', ''): 2214,
#              ('thing', 'ability', ''): 10,
#              ('', 'Limited', ''): 249,
#              ('', 'type', ''): 4220,
#              ('manure', 'fertilize', 'planting'): 1,
#              ('', 'people', ''): 4051,
#              ('Robert', 'win', ''): 3,
#              ('you', 'use', 'card'): 20,
#              ('you', 'start', 'one'): 2,
#              ('', 'from', ''): 160,
#              ('she', 'potential', ''): 1,
#              ('', '&lt', ''): 179,
#              ('', 'chair', ''): 1082,
#              ('', 'stable', ''): 116,
#              ('', 'programming', ''): 178,
#              ('he', 'describe', 'he'): 1,
#              ('I', 'there', ''): 290,
#              ('', 'send', ''): 924,
#              ('', 'result', ''): 5773,
#              ('', 'free', ''): 1116,
#              ('', 'condition', ''): 1838,
#              ('', 'owner', ''): 653,
#              ('policeman', 'follow', 'Havel'): 1,
#              ('time', 'pm', ''): 822,
#              ('image', 'deliver', ''): 5,
#              ('bread', 'hit', ''): 1,
#              ('news', 'feed', ''): 9,
#              ('', 'Ross-Simon', ''): 2,
#              ('I', 'love', 'gingersnaps'): 1,
#              ('Miz', 'last', ''): 1,
#              ('', '...8', ''): 2,
#              ('', 'Larry', ''): 297,
#              ('appears', 'remove', 'Ballgag'): 1,
#              ('you', 'use', 'Pvc'): 1,
#              ('warn', 'be', ''): 5,
#              ('Suffolk', 'see', 'Howard'): 1,
#              ('it', 'color', ''): 42,
#              ('document', 'available', ''): 35,
#              ('glow', 'blind', ''): 1,
#              ('', 'likley', ''): 1,
#              ('we', 'sailing', 'Enthusiasts'): 1,
#              ('', 'right', ''): 1221,
#              ('it', 'take', ''): 798,
#              ('Dolphin', 'miss', 'he'): 1,
#              ('', 'revise', ''): 157,
#              ('I', 'think', 'team'): 7,
#              ('', 'Terry', ''): 401,
#              ('route', 'shut', ''): 4,
#              ('', 'find', 'someone'): 27,
#              ('', 'episode', ''): 3005,
#              ('we', 'give', 'rest'): 1,
#              ('', 'give', 'cash'): 1,
#              ('', 'promise', ''): 358,
#              ('instances', 'be', ''): 48,
#              ('suspect', 'wan', ''): 2,
#              ('', 'cruise', ''): 338,
#              ('you', 'look', ''): 1234,
#              ('', 'initdb', ''): 3,
#              ('man', 'sit', ''): 11,
#              ('part', 'label', ''): 2,
#              ('', 'farm', ''): 457,
#              ('I', 'buy', 'one'): 107,
#              ('', 'PIss', 'off'): 1,
#              ('', 'Vernon', ''): 72,
#              ('we', 'have', 'lunch'): 10,
#              ('', 'manager', ''): 2040,
#              ('this', 'time', ''): 824,
#              ('this', 'deny', ''): 7,
#              ('', 'shrimp', ''): 115,
#              ('', 'read', 'term'): 65,
#              ('fusion', 'speak', ''): 1,
#              ('', 'finger', ''): 192,
#              ('', 'Entries', ''): 134,
#              ('', '@sasilik', ''): 1,
#              ('application', 'one', ''): 4,
#              ('', 'image', ''): 3710,
#              ('I', 'strain', 'weed'): 1,
#              ('', 'dictionary', ''): 1303,
#              ('he', 'dandl', ''): 1,
#              ('Darren', 'say', ''): 13,
#              ('', 'Title', ''): 4420,
#              ('', 'sticker', ''): 179,
#              ('', 'documentary', ''): 145,
#              ('', 'zoo', ''): 90,
#              ('Ewan', 'give', 'author'): 1,
#              ('you', 'help', ''): 225,
#              ('', 'Oldies', ''): 22,
#              ('', 'STATIO', ''): 1,
#              ('they', 'make', 'assessment'): 1,
#              ('', 'much', ''): 1109,
#              ('', 'Chicken', ''): 243,
#              ('', 'Top', ''): 624,
#              ('', 'about', ''): 513,
#              ('', 'make', 'outhouse'): 1,
#              ('', '9th', ''): 436,
#              ('', 'Transformers', ''): 44,
#              ('you', 'agree', ''): 1088,
#              ('', '10', ''): 2931,
#              ('Eustis', 'like', ''): 2,
#              ('hotel', 'show', 'all'): 4,
#              ('', 'help', ''): 2714,
#              ('1880', 'year', ''): 1,
#              ('quality', 'walkability', ''): 1,
#              ('monopolist', 'have', ''): 1,
#              ('people', 'start', ''): 78,
#              ('', 'advocate', ''): 152,
#              ('Union', 'other', ''): 1,
#              ('fastjizz.com', 'have', 'rank'): 1,
#              ('', 'close', ''): 1852,
#              ('it', 'become', ''): 846,
#              ('', 'Damn', ''): 21,
#              ('I', 'assume', ''): 684,
#              ('vegetarians', 'miss', ''): 1,
#              ('', 'dress', ''): 957,
#              ('', 'term', ''): 2432,
#              ('everyone', 'want', ''): 48,
#              ('', 'AP', ''): 131,
#              ('', 'change', ''): 2991,
#              ('drone', 'speak', 'whale'): 1,
#              ('I', 'sure', ''): 5131,
#              ('attention', 'help', 'you'): 4,
#              ('momma', 'ride', 'cock'): 1,
#              ('i', 'glad', ''): 65,
#              ('starts', 'include', 'Whip'): 1,
#              ('you', 'need', 'QSS'): 1,
#              ('', 'beautiful', ''): 265,
#              ('skier', 'enjoy', 'trail'): 1,
#              ('', 'Tshirt', ''): 8,
#              ('Kelly', 'say', ''): 34,
#              ('', 'OldEnglish', ''): 4,
#              ('I', 'have', 'idea'): 787,
#              ('', 'calls', ''): 119,
#              ('', 'February', ''): 2228,
#              ('', 'Tweet', ''): 927,
#              ('', 'Handbook', ''): 325,
#              ('', 'commissioner', ''): 207,
#              ('', 'Smith', ''): 474,
#              ('choice', 'yours', ''): 21,
#              ('Lg', 'pick', 'technology'): 1,
#              ('', 'Wiley', ''): 50,
#              ('', 'win', ''): 1063,
#              ('I', 'believe', ''): 3753,
#              ('', 'Don', ''): 462,
#              ('metal', 'affec', ''): 1,
#              ('I', 'beg', ''): 53,
#              ('', 'U.S.', ''): 596,
#              ('', 'thanks', ''): 12700,
#              ('', 'John.Peters@il.usda.gov', ''): 1,
#              ('', 'get', 'rate'): 51,
#              ('', 'Photogallery', ''): 6,
#              ('area', 'include', 'restaurant'): 2,
#              ('problem', 'be', ''): 1947,
#              ('answer', 'get', 'Mirror'): 1,
#              ('people', 'hold', 'country'): 1,
#              ('', 'May', ''): 6666,
#              ('they', 'provide', 'stack'): 1,
#              ('Santa', 'get', 'toy'): 1,
#              ('', 'Vixely', ''): 2,
#              ('', 'strategy', ''): 397,
#              ('that', 'make', 'huh'): 3,
#              ('', 'Consultant', ''): 165,
#              ('', 'transit', 'manager'): 2,
#              ('', 'Alfre', ''): 4,
#              ('you', 'charge', 'much'): 2,
#              ('she', 'have', 'percent'): 1,
#              ('', 'Coe', ''): 101,
#              ('', 'MLVIX', ''): 1,
#              ('you', 'download', '80'): 1,
#              ('cycle', '2,700', ''): 1,
#              ('Tinker', 'something', ''): 2,
#              ('Linux', 'lose', ''): 6,
#              ('', 'love', 'it'): 199,
#              ('', 'student', ''): 1699,
#              ('Trybunalski', 'visit', 'Poland'): 1,
#              ('', 'bajmurray', ''): 1,
#              ('', 'shut', 'nat'): 1,
#              ('oxidation', 'provide', 'mitochondria'): 1,
#              ('we', 'discuss', 'it'): 5,
#              ('', 'account', ''): 1452,
#              ('he', 'say', ''): 8682,
#              ('fan', 'remember', 'performance'): 2,
#              ('', 'authority', ''): 425,
#              ('she', 'throw', 'arm'): 1,
#              ('I', 'feel', ''): 3797,
#              ('', 'really', ''): 92,
#              ('I', 'learn', ''): 671,
#              ('defeat', 'something', ''): 1,
#              ('message', 'what', ''): 17,
#              ('Daeron', 'become', ''): 1,
#              ('', 'sshakery', ''): 1,
#              ('', 'Pineapple', ''): 14,
#              ('', 'thought', ''): 890,
#              ('', 'board', ''): 1806,
#              ('you', 'start', ''): 406,
#              ('', 'Pgz', ''): 1,
#              ('', ')', ''): 125,
#              ('renewal', 'showcase', 'strength'): 1,
#              ('all', 'antithetical', ''): 1,
#              ('correspondent', 'take', 'trouble'): 1,
#              ('', 'work', 'stress'): 1,
#              ('', 'ICT', ''): 5,
#              ('', 'one', ''): 5519,
#              ('', 'lead', 'delegation'): 4,
#              ('', 'buy', ''): 1187,
#              ('I', 'write', 'post.'): 1,
#              ('', 'forget', ''): 1086,
#              ('', 'night', ''): 2406,
#              ('', 'device', ''): 982,
#              ('', 'order', 'size'): 6,
#              ('', 'open', 'office'): 5,
#              ('we', 'grateful', ''): 103,
#              ('', 'highest', ''): 52,
#              ('', 'Paulus', ''): 5,
#              ('Myagkov', 'expose', ''): 1,
#              ('', 'b.', ''): 840,
#              ('', 'Exchange', ''): 409,
#              ('banner', 'say', ''): 1,
#              ('', 'all', ''): 2552,
#              ('', 'widget', ''): 40,
#              ('i', 'n', ''): 3,
#              ('we', 'lookout', ''): 10,
#              ('', 'HistoricalHilarity', ''): 1,
#              ('Poland', 'join', ''): 1,
#              ('', 'Oct', ''): 1564,
#              ('', 'money', ''): 850,
#              ('', 'SheanElatwebynetnews', ''): 1,
#              ('Harriet', 'play', ''): 1,
#              ('', 'let', 'play'): 12,
#              ('seat', 'fold', 'piece'): 1,
#              ('', 'legion2', ''): 1,
#              ('', 'use', 'red'): 2,
#              ('', 'void', ''): 257,
#              ('', 'speed', ''): 893,
#              ('they', 'work', ''): 438,
#              ('', 'choose', 'meat'): 3,
#              ('', 'welcome', ''): 2854,
#              ('they', 'diva', ''): 1,
#              ('Boulware', 'go', ''): 1,
#              ('people', 'hesitate', ''): 3,
#              ('vocal', 'crisp', ''): 1,
#              ('we', 'guess', ''): 28,
#              ('', 'Oddisee', ''): 13,
#              ('', 'co', ''): 630,
#              ('', 'love', 'colour'): 16,
#              ('', 'need', 'benchmark'): 1,
#              ('', '17', ''): 1362,
#              ('', 'sequence', ''): 310,
#              ('she', 'want', ''): 252,
#              ('Humidifier', 'produce', 'vapor'): 1,
#              ('', 'receive', 'discount'): 7,
#              ('James', 'worried', ''): 1,
#              ('', 'plate', ''): 347,
#              ('system', 'have', 'assembly'): 1,
#              ('this', 'seem', ''): 406,
#              ('support', 'hope', ''): 2,
#              ('', 'Corporation', ''): 542,
#              ('team', 'grow', ''): 1,
#              ('it', 'extend', 'side'): 1,
#              ('', 'Manual', ''): 22,
#              ('', 'section', ''): 1639,
#              ('food', 'great', ''): 42,
#              ('', 'stearate', ''): 3,
#              ('', 'Browser', ''): 25,
#              ('this', 'shock', ''): 6,
#              ('', 'want', 'ad'): 16,
#              ('', 'soon', ''): 479,
#              ('method', 'say', ''): 116,
#              ('6', 'say', ''): 2,
#              ('', 'report', ''): 6537,
#              ('i', 'know', 'practice'): 1,
#              ('you', 'add', 'filter'): 1,
#              ('', 'live', ''): 1821,
#              ('he', 'want', ''): 499,
#              ('FIG.', 'chart', ''): 51,
#              ('', 'engage', ''): 229,
#              ('', 'review', ''): 9635,
#              ('Campaigns', 'obfuscate', ''): 1,
#              ('i', 'think', ''): 1075,
#              ('I', 'take', 'reference'): 1,
#              ('name', 'mean', 'friend'): 2,
#              ('', 'thats', ''): 51,
#              ('it', 'remind', 'I'): 189,
#              ('', 'solenoid', ''): 6,
#              ('Anne', 'spread', 'view'): 1,
#              ('you', 'let', 'management'): 1,
#              ('', 'spend', 'day'): 24,
#              ('Williams', 'blame', 'liberal'): 1,
#              ('', 'Takahisa', ''): 7,
#              ('', 'Vacationist', ''): 2,
#              ('', '1970', ''): 448,
#              ('I', 'live', ''): 1193,
#              ('guy', 'have', 'array'): 1,
#              ('', 'epic', ''): 20,
#              ('', 'Friday', ''): 2480,
#              ('', 'BlogEntry', ''): 10,
#              ('', 'awards', ''): 1172,
#              ('', 'secrets', ''): 180,
#              ('they', 'singe', 'version'): 1,
#              ('station', 'use', 'moniker'): 1,
#              ('Committee', 'suggest', ''): 1,
#              ('I', 'wake', ''): 164,
#              ('member', 'dimension', ''): 1,
#              ('', 'ring', ''): 1074,
#              ('', 'Jeffords', ''): 1,
#              ('group', 'put', 'fruit'): 1,
#              ('', 'agent', ''): 575,
#              ('this', 'allow', 'you'): 94,
#              ('', '10.1111/j.1399-5618.2010.00817.x©', ''): 1,
#              ('', 'sex', ''): 816,
#              ('civilisation', 'world', ''): 1,
#              ('tm', 'mark', ''): 1,
#              ('candidacy', 'come', ''): 1,
#              ('government', 'consider', ''): 9,
#              ('you', 'who', ''): 30,
#              ('Roundup', 'publish', ''): 1,
#              ('', 'play', 'field'): 5,
#              ('', 'Sweatshirt', ''): 26,
#              ('Shinji', 'become', 'victim'): 1,
#              ('', 'apply', 'filter'): 1,
#              ('we', 'shut', 'car'): 1,
#              ('', 'Years', ''): 441,
#              ('', 'tune', ''): 233,
#              ('old', 'say', ''): 11,
#              ('commerce', 'create', 'demand'): 1,
#              ('', 'Torque', ''): 27,
#              ('president', 'appear', ''): 1,
#              ('tap', 'cock', ''): 1,
#              ('', 'adventure', ''): 457,
#              ('need', 'be', ''): 531,
#              ('I', 'wonder', ''): 2530,
#              ('I', 'trust', 'Korea'): 2,
#              ('', 'fit', ''): 715,
#              ('', 'management', ''): 1431,
#              ('count', 'cease', ''): 1,
#              ('', 'burner', ''): 71,
#              ('', 'Tue', ''): 798,
#              ('we', 'kick', ''): 13,
#              ('', 'fall', ''): 1204,
#              ('I', 'absorb', 'trick'): 1,
#              ('you', 'check', 'peek'): 1,
#              ('', '23k', ''): 1,
#              ('', 'late', ''): 263,
#              ('', 'Mr.', ''): 2901,
#              ('Walton', 'continue', 'subject'): 1,
#              ('access', 'hatch', ''): 3,
#              ('', 'technique', ''): 533,
#              ('Descarte', 'continue', ''): 2,
#              ('way', 'be', ''): 2826,
#              ('I', 'fix', 'gap'): 1,
#              ('footing', 'precast', ''): 1,
#              ('', "#_widget1892947942174'", ''): 1,
#              ('it', 'nice', ''): 428,
#              ('', 'schedule', ''): 1000,
#              ('I', 'get', 'naked'): 2,
#              ('machine', 'wash', 'cycle'): 2,
#              ('', 'photo', ''): 7033,
#              ('', '1765', ''): 5,
#              ('', 'counselor', ''): 93,
#              ('Lesbians', 'have', 'sex'): 2,
#              ('this', 'set', ''): 93,
#              ('assurance', 'include', ''): 7,
#              ('', 'Felix', ''): 76,
#              ('schedule', 'include', 'show'): 2,
#              ('', 'angle', ''): 149,
#              ('we', 'have', 'crepe'): 1,
#              ('Jews', 'live', ''): 7,
#              ('', 'failure', ''): 533,
#              ('', 'Cyclone', ''): 19,
#              ('', 'Blue', ''): 828,
#              ('President', 'deliver', 'address'): 5,
#              ('sergean', 'die', 'monday'): 1,
#              ('', 'review', 'post'): 4,
#              ('', 'Im', ''): 231,
#              ('', 'AMd', ''): 20,
#              ('', 'movie', ''): 2013,
#              ('neighbor', 'have', 'problem'): 1,
#              ('', 'Vanessa', ''): 49,
#              ('I', 'start', ''): 1753,
#              ('', 'cake', ''): 897,
#              ('', 'travel', 'regulation'): 2,
#              ('', 'we', ''): 1539,
#              ('', 'Andi', ''): 7,
#              ('', 'connections', ''): 97,
#              ('company', 'introduce', 'card'): 1,
#              ('afternoon', 'say', ''): 1,
#              ('', 'claims', ''): 156,
#              ('', 'do', 'something'): 72,
#              ('feature', 'disable', ''): 9,
#              ('mask', 'provide', 'hydration'): 1,
#              ('John', 'need', 'shade'): 1,
#              ('you', 'note', 'spelling'): 1,
#              ('', 'check', ''): 3288,
#              ('i', 'Hoteller', ''): 1,
#              ('', 'for', ''): 531,
#              ('can', 'intake', ''): 2,
#              ('', 'edit', ''): 2578,
#              ('', 'bench', ''): 102,
#              ('', 'launch', 'it'): 3,
#              ('', 'Intro', ''): 126,
#              ('window', 'redesign', ''): 1,
#              ('', 'Yakuza', ''): 3,
#              ('Skirts', 'require', ''): 1,
#              ('GAB', 'set', ''): 1,
#              ('you', 'like', 'who'): 15,
#              ('I', 'certain', ''): 221,
#              ('I', 'like', 'fox'): 1,
#              ('I', 'have', 'on'): 2,
#              ('', 'leave', 'idea'): 2,
#              ('', 'Design', 'contest'): 4,
#              ('Sou', 'pick', ''): 1,
#              ('', 'name', ''): 6545,
#              ('people', 'do', 'much'): 2,
#              ('', 'ml', ''): 302,
#              ('', 'Riverside', ''): 84,
#              ('drive', 'utilize', ''): 1,
#              ('Matt', 'give', 'insight'): 1,
#              ('channels', 'intercouple', '-pressure'): 1,
#              ('I', 'have', 'car'): 27,
#              ('', 'equip', ''): 120,
#              ('Yanukovych', 'elect', ''): 1,
#              ('', 'move', 'reader'): 1,
#              ('', 'tell', ''): 1132,
#              ('', '2.0', ''): 135,
#              ('', 'see', 'synonym'): 23,
#              ('', 'band', ''): 1012,
#              ('', 'official', ''): 512,
#              ('', 'FlightAware', ''): 44,
#              ('', 'Spider', ''): 57,
#              ('he', 'want', 'cas'): 1,
#              ('this', 'classroom', ''): 1,
#              ('', 'offer', ''): 930,
#              ('', 'communication', ''): 403,
#              ('', 'master', ''): 815,
#              ('', 'D800', ''): 27,
#              ('member', 'produce', 'bean'): 1,
#              ('', 'Double', ''): 99,
#              ('lack', 'seem', ''): 7,
#              ('', 'raise', ''): 190,
#              ('', 'facility', ''): 1024,
#              ('Celebrity', 'Birthdays', ''): 1,
#              ('quote', 'have', ''): 12,
#              ('belief', 'be', ''): 72,
#              ('it', 'time', ''): 2514,
#              ('', 'marry', 'Norda'): 1,
#              ...})

# %%
df[(df.subj != '') & (df.obj != '')].sort_values('freq', ascending=False).head()

# %%
import io
import pickle

# Use the pure-Python version, we can't see the internal state of the C version
pickle.Unpickler = pickle._Unpickler

import dill

if __name__ == '__main__':
    unpickler = dill.Unpickler(open('/mnt/store/home/makrai/project/verb-tensor/umbc_freq.pkl', mode='rb'))

    try:
        unpickler.load()
    except EOFError:
        pass

    print(unpickler.stack)
# Out:
# [('', 'SCabello', ''), 1, ('islander', 'sense', ''), 1, ('powertrain', 'turn', ''), 1, ('', 'Smoulder', 'work'), 1, ('these', 'reak', ''), 1, ('June', 'waive', 'right'), 1, ('', 'photo-5294048.71699', ''), 1, ('', 'contact', 'Aitken'), 1, ('you', 'cycle', '3.5g'), 1, ('tronage', 'l', ''), 1, ('Diamond', 'Mirror', 'Glass'), 1, ('I', 'mean', 'pregnancy'), 1, ('mother', 'hold', 'peace'), 1, ('', 'Exterminat', 'people'), 1, ('hour', 'have', 'cent'), 1, ('organizer', 'elect', 'President'), 1, ('', '240471', ''), 1, ('we', 'acknowledge', 'obvious'), 1, ('drow', 'capable', ''), 1, ('', 'ReplyDeletelife.w.purposeJanuary', ''), 1, ('', 'EUFIC', ''), 2, ('J', 'name', 'person'), 1, ('musicians', 'play', 'part'), 1, ('telemarketer', 'convince', 'charity'), 1, ('priest', 'utilize', 'device'), 1, ('contribution', 'help', 'organisation'), 1, ('wine', 'letter', ''), 1, ('treatment', 'relief', 'lapse'), 2, ('I', 'agree', 'finance'), 1, ('we', 'provide', 'cups'), 1, ('appliance', 'deliver', 'class'), 1, ('Invest', 'cost', 'AdvantageAugust'), 1, ('physicians', 'Hasan', ''), 1, ('index', 'suggest', 'path'), 1, ('Motta', 'keep', 'standards'), 1, ('', 'DCL9848Price', ''), 1, ('Defense', 'undate', ''), 1, ('Wilde', 'know', 'stuff'), 2, ('privacy', 'whole', ''), 1, ('python', 'film', ''), 1, ('Rich', 'co-author', 'article'), 1, ('monitoring', 'provide', 'system'), 1, ('we', 'preferred', 'option'), 1, ('ap', 'have', 'issue'), 1, ('Zadie', 'admit', 'block'), 1, ('picture', 'capture', 'presence'), 1, ('bond', 'expos', ''), 1, ('li', 'lead', 'agency'), 1, ('', '15856', ''), 1, ('', 'clean', 'Shelving'), 2, ('Violoa', 'claim', ''), 1, ('Cubit', 'coach', ''), 1, ('fo', 'another', ''), 1, ('agreement', 'state', 'name'), 1, ('Reflector', 'time', ''), 1, ('Maryland', 'shut', ''), 1, ('lisa', 'need', 'brace'), 5, ('vh', 'copy', ''), 2, ('Untimely', 'drive', ''), 1, ('Salaita', 'have', 'stage'), 1, ('', 'hanes.com', ''), 1, ('Duchess', "'hote", ''), 1, ('1e', 'conservative', ''), 1, ('-8', 'jack', ''), 1, ('Scott', 'midst', ''), 1, ('explorer', 'consul', ''), 1, ('Harry', 'get', 'support'), 2, ('b', 'wip', ''), 1, ('', 'Conselho', ''), 1, ('nor', 'do', 'abstain'), 1, ('BadNew', 'fold', ''), 1, ('I', 'reconomend', 'series'), 1, ('that', 'seem', 'Pragâpati'), 2, ('I', 'dig', 'jacket'), 1, ('Clark', 'apologize', ''), 1, ('Kent', 'grace', ''), 1, ('company', 'trade', 'trade'), 1, ('we', 'break', 'relation'), 1, ('studio', 'insulate', ''), 3, ('', 'SimplePup', ''), 1, ('call', 'abominable', ''), 2, ('v6.1', 'run', ''), 1, ('', 'rakan_b52', ''), 1, ('bridesmaid', 'appear', ''), 1, ('', 'Metaxya', ''), 1, ('point', 'Prague', ''), 1, ('race', 'Blackness', ''), 1, ('flagyl', 'serve', 'candida'), 1, ('Saavedra', 'run', ''), 1, ('mark', '388', ''), 1, ('Lament', 'have', 'everything'), 2, ('cleric', 'cleare', ''), 1, ('Dolls', 'steal', 'heart'), 1, ('', '@GridironExpert', ''), 1, ('', 'AccessoriesFootwear', ''), 2, ('', 'ncome', 'section'), 1, ('31', 'record', ''), 1, ('j', 'consider', 'news'), 1, ('you', 'hang', 'belt'), 2, ('WACC', 'constant', ''), 1, ('lifetime', 'brush', ''), 1, ('Woodhouse', 'athlete', ''), 1, ('Calm', 'ready', ''), 4, ('', 'View', 'Bonaventure'), 1, ('assume', 'erroneous', ''), 1, ('', 'Worshipp', 'Bible'), 1, ('issue', 'know', 'punishment'), 1, ('', 'Exaggerate', 'distance'), 1, ('Sunrise', 'have', 'some'), 1, ('', 'Leak', 'Feb-6-2009'), 1, ('virtue', 'magnanimity', ''), 1, ('Henrico', 'carry', 'name'), 1, ('truth', 'impart', ''), 1, ('', 'use', 'DENSI2010'), 1, ('Morley', 'talks', ''), 1, ('', 'brillito', ''), 1, ('', 'Bliss', '30'), 1, ('Chicago', 'richer', ''), 1, ('', 'MoreAllAllStationsArtistsSongsOriginalsPodcastsKOLT', ''), 1, ('', 'select', 'Computer_idn'), 1, ('clients', 'Michelle', ''), 1, ('Office', 'fuck', 'assistant'), 1, ('goo.gl/awzuuq', '@heartiste', ''), 1, ('open', 'cause', 'behavior'), 1, ('', 'Tag', 'BDRA'), 1, ('', 'horrify', 'kumu'), 1, ('', 'refugee.', ''), 1, ('class', 'recital', ''), 1, ('websiteSearchI', 'like', ''), 1, ('m ...
